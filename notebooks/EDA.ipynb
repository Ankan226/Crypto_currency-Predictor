# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns


df = pd.read_csv("../data/processed_crypto_data.csv")


print(df.describe())


# closing price distribution
plt.figure()
sns.histplot(df["close"])
plt.title("Closing Price Distribution")
plt.show()


# price comparison across cryptocurrencies
plt.figure()
sns.boxplot(x="crypto_name", y="close", data=df)
plt.title("Price by Cryptocurrency")
plt.show()


# correlation heatmap (numeric columns only)
numeric_df = df.select_dtypes(include=["float64", "int64"])

plt.figure(figsize=(10,8))
sns.heatmap(numeric_df.corr(), annot=True, cmap="coolwarm")

plt.title("Correlation Matrix")
plt.show()
# Out:
#                open           high           low         close        volume  \
# count  69506.000000   69506.000000  69506.000000  69506.000000  6.950600e+04
# mean     892.318296     918.850747    865.674437    893.364700  2.314347e+09
# std     5344.226337    5514.406751   5188.937768   5348.078055  9.840606e+09
# min        0.000003       0.000006      0.000003      0.000006  0.000000e+00
# 25%        0.163599       0.172775      0.155273      0.163989  1.077161e+07
# 50%        1.526816       1.607021      1.446800      1.530330  1.267884e+08
# 75%       28.696712      30.090239     27.324031     28.760395  7.409175e+08
# max    67549.735581  162188.255437  66458.723733  67566.830088  3.509679e+11
#
#           marketCap           MA7          MA30    volatility  \
# count  6.950600e+04  69506.000000  69506.000000  69506.000000
# mean   1.546343e+10    892.122824    886.676011     40.148512
# std    7.677353e+10   5340.097538   5307.941087    262.475017
# min    2.516000e+05      0.000004      0.000002      0.000000
# 25%    2.407418e+08      0.163955      0.165223      0.003317
# 50%    1.444943e+09      1.536263      1.529249      0.071199
# 75%    5.508123e+09     28.859518     28.568184      1.673348
# max    1.274831e+12  65425.441580  62470.502033   5027.702349
#
#        liquidity_ratio    price_range
# count     69506.000000   69506.000000
# mean          0.253020      53.176310
# std           0.708731     544.144017
# min           0.000000       0.000000
# 25%           0.027241       0.006417
# 50%           0.076930       0.098691
# 75%           0.210500       2.223000
# max          21.401189  103899.079895
